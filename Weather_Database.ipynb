# %%
# Import the dependencies.
from citipy import citipy
import numpy as np
import pandas as pd
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %%
# Import the requests library.
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | novobirilyussy
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | magnolia
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | port hardy
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | victoria
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | mayor pablo lagerenza
# Processing Record 24 of Set 1 | barretos
# Processing Record 25 of Set 1 | tuatapere
# Processing Record 26 of Set 1 | prince george
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | geraldton
# Processing Record 30 of Set 1 | kyren
# Processing Record 31 of Set 1 | ust-kuyga
# Processing Record 32 of Set 1 | watsa
# Processing Record 33 of Set 1 | komsomolskiy
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | suluq
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | puerto carreno
# Processing Record 41 of Set 1 | bubaque
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | dingle
# Processing Record 44 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 1 | shingu
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | plettenberg bay
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | coos bay
# Processing Record 2 of Set 2 | yar-sale
# Processing Record 3 of Set 2 | denpasar
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | upata
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | barra patuca
# Processing Record 8 of Set 2 | fuerte olimpo
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | howard springs
# Processing Record 11 of Set 2 | te anau
# Processing Record 12 of Set 2 | nsanje
# Processing Record 13 of Set 2 | monrovia
# Processing Record 14 of Set 2 | korla
# Processing Record 15 of Set 2 | nouakchott
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | trinidad
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | umm lajj
# Processing Record 24 of Set 2 | cayenne
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | dharmabad
# Processing Record 27 of Set 2 | mildura
# Processing Record 28 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | narsaq
# Processing Record 31 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 2 | asau
# Processing Record 33 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 2 | sobolevo
# Processing Record 35 of Set 2 | port hedland
# Processing Record 36 of Set 2 | taoudenni
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | muli
# Processing Record 39 of Set 2 | meulaboh
# Processing Record 40 of Set 2 | jurado
# Processing Record 41 of Set 2 | saint-raphael
# Processing Record 42 of Set 2 | muravlenko
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | bhabua
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | lexington
# Processing Record 47 of Set 2 | saint-joseph
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | saint-francois
# Processing Record 1 of Set 3 | santa maria
# Processing Record 2 of Set 3 | redditch
# Processing Record 3 of Set 3 | cap malheureux
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | roma
# Processing Record 6 of Set 3 | lyubytino
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | palmer
# Processing Record 9 of Set 3 | dutlwe
# Processing Record 10 of Set 3 | durusu
# Processing Record 11 of Set 3 | tongchuan
# Processing Record 12 of Set 3 | ulaangom
# Processing Record 13 of Set 3 | lengshuitan
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | singaraja
# Processing Record 16 of Set 3 | kongoussi
# Processing Record 17 of Set 3 | busselton
# Processing Record 18 of Set 3 | sassandra
# Processing Record 19 of Set 3 | dalvik
# Processing Record 20 of Set 3 | tarata
# Processing Record 21 of Set 3 | chumikan
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | kandrian
# Processing Record 24 of Set 3 | taguatinga
# Processing Record 25 of Set 3 | lensk
# Processing Record 26 of Set 3 | mizdah
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | kyra
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | himora
# City not found. Skipping...
# Processing Record 32 of Set 3 | coquimbo
# Processing Record 33 of Set 3 | kupang
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | poshekhonye
# Processing Record 37 of Set 3 | tres arroyos
# Processing Record 38 of Set 3 | bandarbeyla
# Processing Record 39 of Set 3 | pithoragarh
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | carlsbad
# Processing Record 42 of Set 3 | new ross
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 3 | ulefoss
# Processing Record 45 of Set 3 | trabzon
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | milledgeville
# Processing Record 48 of Set 3 | qasigiannguit
# Processing Record 49 of Set 3 | ovalle
# Processing Record 50 of Set 3 | ullapool
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | fortuna
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | tabou
# Processing Record 5 of Set 4 | koumac
# Processing Record 6 of Set 4 | aguimes
# Processing Record 7 of Set 4 | isabela
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | zhangye
# Processing Record 10 of Set 4 | buluang
# Processing Record 11 of Set 4 | nome
# Processing Record 12 of Set 4 | axim
# Processing Record 13 of Set 4 | iberia
# Processing Record 14 of Set 4 | tazovskiy
# Processing Record 15 of Set 4 | valdez
# Processing Record 16 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 4 | sao mateus do maranhao
# Processing Record 18 of Set 4 | hvolsvollur
# Processing Record 19 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | lazaro cardenas
# Processing Record 22 of Set 4 | faya
# Processing Record 23 of Set 4 | funtua
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | kamphaeng phet
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | turayf
# Processing Record 28 of Set 4 | grants pass
# Processing Record 29 of Set 4 | dolinsk
# Processing Record 30 of Set 4 | poum
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | gat
# Processing Record 33 of Set 4 | broome
# Processing Record 34 of Set 4 | santa isabel do rio negro
# Processing Record 35 of Set 4 | griffith
# Processing Record 36 of Set 4 | merauke
# Processing Record 37 of Set 4 | tananger
# Processing Record 38 of Set 4 | derzhavinsk
# Processing Record 39 of Set 4 | khatassy
# Processing Record 40 of Set 4 | belmonte
# Processing Record 41 of Set 4 | buritama
# Processing Record 42 of Set 4 | mirina
# City not found. Skipping...
# Processing Record 43 of Set 4 | seljord
# Processing Record 44 of Set 4 | lata
# Processing Record 45 of Set 4 | vanimo
# Processing Record 46 of Set 4 | mananjary
# Processing Record 47 of Set 4 | leningradskiy
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | sascut
# Processing Record 50 of Set 4 | bam
# Processing Record 1 of Set 5 | ust-kan
# Processing Record 2 of Set 5 | kralendijk
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | juneau
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | samarai
# Processing Record 8 of Set 5 | amaigbo
# Processing Record 9 of Set 5 | constitucion
# Processing Record 10 of Set 5 | smirnykh
# Processing Record 11 of Set 5 | el estor
# Processing Record 12 of Set 5 | mantua
# Processing Record 13 of Set 5 | mbaiki
# Processing Record 14 of Set 5 | chifeng
# Processing Record 15 of Set 5 | balclutha
# Processing Record 16 of Set 5 | puerto del rosario
# Processing Record 17 of Set 5 | chuy
# Processing Record 18 of Set 5 | harper
# Processing Record 19 of Set 5 | kailua
# Processing Record 20 of Set 5 | gumdag
# Processing Record 21 of Set 5 | medicine hat
# Processing Record 22 of Set 5 | kloulklubed
# Processing Record 23 of Set 5 | abrau-dyurso
# Processing Record 24 of Set 5 | nisia floresta
# Processing Record 25 of Set 5 | evensk
# Processing Record 26 of Set 5 | bolshoy uluy
# City not found. Skipping...
# Processing Record 27 of Set 5 | hamilton
# Processing Record 28 of Set 5 | san cristobal
# Processing Record 29 of Set 5 | sibolga
# Processing Record 30 of Set 5 | broken hill
# Processing Record 31 of Set 5 | matara
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | manta
# Processing Record 34 of Set 5 | airai
# Processing Record 35 of Set 5 | honolulu
# Processing Record 36 of Set 5 | bowmore
# Processing Record 37 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 5 | huilong
# Processing Record 40 of Set 5 | sao felix do xingu
# Processing Record 41 of Set 5 | basoko
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | bose
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | haikou
# Processing Record 47 of Set 5 | zyryanka
# Processing Record 48 of Set 5 | xining
# Processing Record 49 of Set 5 | flinders
# Processing Record 50 of Set 5 | saldanha
# Processing Record 1 of Set 6 | port augusta
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | aksum
# Processing Record 5 of Set 6 | the pas
# Processing Record 6 of Set 6 | los llanos de aridane
# Processing Record 7 of Set 6 | port-gentil
# Processing Record 8 of Set 6 | ucluelet
# Processing Record 9 of Set 6 | manakara
# Processing Record 10 of Set 6 | mayo
# Processing Record 11 of Set 6 | kungalv
# Processing Record 12 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 6 | ixtapa
# Processing Record 14 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 6 | belyy yar
# Processing Record 16 of Set 6 | port moresby
# Processing Record 17 of Set 6 | chokurdakh
# Processing Record 18 of Set 6 | sur
# Processing Record 19 of Set 6 | kumluca
# Processing Record 20 of Set 6 | riyadh
# Processing Record 21 of Set 6 | balabac
# Processing Record 22 of Set 6 | norman wells
# Processing Record 23 of Set 6 | klaksvik
# Processing Record 24 of Set 6 | severomuysk
# Processing Record 25 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 26 of Set 6 | vardo
# Processing Record 27 of Set 6 | mahdalynivka
# Processing Record 28 of Set 6 | ust-kut
# Processing Record 29 of Set 6 | kaiyuan
# Processing Record 30 of Set 6 | saint-michel-des-saints
# Processing Record 31 of Set 6 | salalah
# Processing Record 32 of Set 6 | valledupar
# Processing Record 33 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 6 | yumen
# Processing Record 35 of Set 6 | el alto
# Processing Record 36 of Set 6 | severo-kurilsk
# Processing Record 37 of Set 6 | saint-philippe
# Processing Record 38 of Set 6 | natal
# Processing Record 39 of Set 6 | shache
# Processing Record 40 of Set 6 | yanam
# Processing Record 41 of Set 6 | pauini
# Processing Record 42 of Set 6 | erdenet
# Processing Record 43 of Set 6 | mandya
# Processing Record 44 of Set 6 | pagudpud
# Processing Record 45 of Set 6 | hvide sande
# Processing Record 46 of Set 6 | odweyne
# Processing Record 47 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 48 of Set 6 | ishigaki
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | arauca
# Processing Record 1 of Set 7 | kalemie
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | lisakovsk
# Processing Record 4 of Set 7 | agadir
# Processing Record 5 of Set 7 | sheregesh
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | mlimba
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | isangel
# Processing Record 10 of Set 7 | ukiah
# Processing Record 11 of Set 7 | adrar
# Processing Record 12 of Set 7 | yining
# Processing Record 13 of Set 7 | polyarnyy
# Processing Record 14 of Set 7 | sorland
# Processing Record 15 of Set 7 | snyder
# Processing Record 16 of Set 7 | praxedis guerrero
# Processing Record 17 of Set 7 | salvador
# Processing Record 18 of Set 7 | arlit
# Processing Record 19 of Set 7 | atbasar
# Processing Record 20 of Set 7 | corbelia
# Processing Record 21 of Set 7 | walvis bay
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | sotouboua
# Processing Record 24 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 7 | bay roberts
# Processing Record 26 of Set 7 | gigmoto
# Processing Record 27 of Set 7 | kahului
# Processing Record 28 of Set 7 | krasnovishersk
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | mahebourg
# Processing Record 31 of Set 7 | nikolskoye
# Processing Record 32 of Set 7 | havre-saint-pierre
# Processing Record 33 of Set 7 | siocon
# Processing Record 34 of Set 7 | sungaipenuh
# Processing Record 35 of Set 7 | sikonge
# Processing Record 36 of Set 7 | siuna
# Processing Record 37 of Set 7 | nyimba
# Processing Record 38 of Set 7 | cabo san lucas
# Processing Record 39 of Set 7 | huancavelica
# Processing Record 40 of Set 7 | kieta
# Processing Record 41 of Set 7 | mehamn
# Processing Record 42 of Set 7 | christchurch
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | vryburg
# Processing Record 45 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 7 | marzuq
# Processing Record 47 of Set 7 | hailar
# Processing Record 48 of Set 7 | tadine
# Processing Record 49 of Set 7 | rocha
# Processing Record 50 of Set 7 | illapel
# Processing Record 1 of Set 8 | los alamos
# Processing Record 2 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 8 | batemans bay
# Processing Record 4 of Set 8 | breves
# Processing Record 5 of Set 8 | yerraguntla
# Processing Record 6 of Set 8 | pokosnoye
# Processing Record 7 of Set 8 | staryy nadym
# Processing Record 8 of Set 8 | burica
# City not found. Skipping...
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | omsukchan
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | huacho
# Processing Record 13 of Set 8 | whitehorse
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | bisira
# Processing Record 16 of Set 8 | cidreira
# Processing Record 17 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | kuching
# Processing Record 19 of Set 8 | kolondieba
# Processing Record 20 of Set 8 | simplicio mendes
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | tucurui
# Processing Record 23 of Set 8 | watertown
# Processing Record 24 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 8 | akureyri
# Processing Record 26 of Set 8 | salinopolis
# Processing Record 27 of Set 8 | nalut
# Processing Record 28 of Set 8 | baykit
# Processing Record 29 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 8 | torres
# Processing Record 31 of Set 8 | kampene
# Processing Record 32 of Set 8 | payson
# Processing Record 33 of Set 8 | lucapa
# Processing Record 34 of Set 8 | matagami
# Processing Record 35 of Set 8 | san andres
# Processing Record 36 of Set 8 | sterling
# Processing Record 37 of Set 8 | havelock
# Processing Record 38 of Set 8 | knysna
# Processing Record 39 of Set 8 | mangan
# Processing Record 40 of Set 8 | teguise
# Processing Record 41 of Set 8 | mackay
# Processing Record 42 of Set 8 | hualmay
# Processing Record 43 of Set 8 | reconquista
# Processing Record 44 of Set 8 | ciudad bolivar
# Processing Record 45 of Set 8 | kristiansund
# Processing Record 46 of Set 8 | byron bay
# Processing Record 47 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 8 | sabha
# Processing Record 49 of Set 8 | kinsale
# Processing Record 50 of Set 8 | voh
# Processing Record 1 of Set 9 | pangkalanbuun
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | okhotsk
# Processing Record 4 of Set 9 | tiksi
# Processing Record 5 of Set 9 | colac
# Processing Record 6 of Set 9 | uthal
# Processing Record 7 of Set 9 | maumere
# Processing Record 8 of Set 9 | quelimane
# Processing Record 9 of Set 9 | bitkine
# Processing Record 10 of Set 9 | kemijarvi
# Processing Record 11 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 9 | lhuntshi
# City not found. Skipping...
# Processing Record 13 of Set 9 | lavrentiya
# Processing Record 14 of Set 9 | bridlington
# Processing Record 15 of Set 9 | eureka
# Processing Record 16 of Set 9 | biltine
# Processing Record 17 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | bojonegoro
# Processing Record 20 of Set 9 | bela
# Processing Record 21 of Set 9 | macenta
# Processing Record 22 of Set 9 | pacific grove
# Processing Record 23 of Set 9 | casper
# Processing Record 24 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 9 | nueva gorgona
# Processing Record 26 of Set 9 | luganville
# Processing Record 27 of Set 9 | nishihara
# Processing Record 28 of Set 9 | dingolfing
# Processing Record 29 of Set 9 | teya
# Processing Record 30 of Set 9 | priiskovyy
# Processing Record 31 of Set 9 | khovu-aksy
# Processing Record 32 of Set 9 | kadirli
# Processing Record 33 of Set 9 | buin
# Processing Record 34 of Set 9 | rio gallegos
# Processing Record 35 of Set 9 | talnakh
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | mayenne
# Processing Record 38 of Set 9 | luwuk
# Processing Record 39 of Set 9 | ormara
# Processing Record 40 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 9 | kamenka
# Processing Record 42 of Set 9 | moron
# Processing Record 43 of Set 9 | karratha
# Processing Record 44 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 9 | portland
# Processing Record 46 of Set 9 | koulamoutou
# Processing Record 47 of Set 9 | dengzhou
# Processing Record 48 of Set 9 | iracoubo
# Processing Record 49 of Set 9 | westport
# Processing Record 50 of Set 9 | roald
# Processing Record 1 of Set 10 | netarhat
# Processing Record 2 of Set 10 | tezu
# Processing Record 3 of Set 10 | grand-santi
# Processing Record 4 of Set 10 | osakarovka
# Processing Record 5 of Set 10 | akhtubinsk
# Processing Record 6 of Set 10 | den helder
# Processing Record 7 of Set 10 | khed
# Processing Record 8 of Set 10 | susangerd
# Processing Record 9 of Set 10 | jasper
# Processing Record 10 of Set 10 | luderitz
# Processing Record 11 of Set 10 | mirnyy
# Processing Record 12 of Set 10 | oistins
# Processing Record 13 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 10 | bograd
# Processing Record 15 of Set 10 | oranjemund
# Processing Record 16 of Set 10 | makakilo city
# Processing Record 17 of Set 10 | brae
# Processing Record 18 of Set 10 | brejo
# Processing Record 19 of Set 10 | turukhansk
# Processing Record 20 of Set 10 | virginia beach
# Processing Record 21 of Set 10 | tranas
# Processing Record 22 of Set 10 | san patricio
# Processing Record 23 of Set 10 | kavaratti
# Processing Record 24 of Set 10 | balotra
# Processing Record 25 of Set 10 | goya
# Processing Record 26 of Set 10 | abashiri
# Processing Record 27 of Set 10 | high level
# Processing Record 28 of Set 10 | sao joao da barra
# Processing Record 29 of Set 10 | lansing
# Processing Record 30 of Set 10 | zhigansk
# Processing Record 31 of Set 10 | rodrigues alves
# Processing Record 32 of Set 10 | mantes-la-jolie
# Processing Record 33 of Set 10 | hambantota
# Processing Record 34 of Set 10 | lebork
# Processing Record 35 of Set 10 | sarankhola
# Processing Record 36 of Set 10 | vestmannaeyjar
# Processing Record 37 of Set 10 | genhe
# Processing Record 38 of Set 10 | barnsley
# Processing Record 39 of Set 10 | liverpool
# Processing Record 40 of Set 10 | caravelas
# Processing Record 41 of Set 10 | langxiang
# Processing Record 42 of Set 10 | sarkand
# Processing Record 43 of Set 10 | tahoua
# Processing Record 44 of Set 10 | russell
# Processing Record 45 of Set 10 | pravia
# Processing Record 46 of Set 10 | toowoomba
# Processing Record 47 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 48 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | bobrovytsya
# Processing Record 50 of Set 10 | zhetybay
# City not found. Skipping...
# Processing Record 1 of Set 11 | paamiut
# Processing Record 2 of Set 11 | kaeo
# Processing Record 3 of Set 11 | ozernovskiy
# Processing Record 4 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 11 | warrnambool
# Processing Record 6 of Set 11 | linjiang
# Processing Record 7 of Set 11 | hangu
# Processing Record 8 of Set 11 | comodoro rivadavia
# Processing Record 9 of Set 11 | estelle
# Processing Record 10 of Set 11 | karlstad
# Processing Record 11 of Set 11 | abbeville
# Processing Record 12 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 13 of Set 11 | copperas cove
# Processing Record 14 of Set 11 | hasaki
# Processing Record 15 of Set 11 | khandbari
# Processing Record 16 of Set 11 | la esperanza
# Processing Record 17 of Set 11 | giaginskaya
# Processing Record 18 of Set 11 | akyab
# Processing Record 19 of Set 11 | reitz
# Processing Record 20 of Set 11 | angoche
# Processing Record 21 of Set 11 | azanka
# Processing Record 22 of Set 11 | general bravo
# Processing Record 23 of Set 11 | kosonsoy
# Processing Record 24 of Set 11 | mount gambier
# Processing Record 25 of Set 11 | waipawa
# Processing Record 26 of Set 11 | north bend
# Processing Record 27 of Set 11 | rawson
# Processing Record 28 of Set 11 | vao
# Processing Record 29 of Set 11 | saint-augustin
# Processing Record 30 of Set 11 | san antonio
# Processing Record 31 of Set 11 | magadan
# Processing Record 32 of Set 11 | santol
# Processing Record 33 of Set 11 | caluquembe
# Processing Record 34 of Set 11 | baturaja
# Processing Record 35 of Set 11 | ust-nera
# Processing Record 36 of Set 11 | leh
# Processing Record 37 of Set 11 | tautira
# Processing Record 38 of Set 11 | aksu
# Processing Record 39 of Set 11 | oksfjord
# Processing Record 40 of Set 11 | naqadeh
# Processing Record 41 of Set 11 | petrovskiy
# Processing Record 42 of Set 11 | rosarito
# Processing Record 43 of Set 11 | kolyvan
# Processing Record 44 of Set 11 | santiago de cuba
# Processing Record 45 of Set 11 | yerbogachen
# Processing Record 46 of Set 11 | bilibino
# Processing Record 47 of Set 11 | santa cruz
# Processing Record 48 of Set 11 | luau
# Processing Record 49 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 11 | karaidel
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | omboue
# Processing Record 3 of Set 12 | tshikapa
# Processing Record 4 of Set 12 | meadow lake
# Processing Record 5 of Set 12 | cascais
# Processing Record 6 of Set 12 | varhaug
# Processing Record 7 of Set 12 | businga
# Processing Record 8 of Set 12 | abu samrah
# Processing Record 9 of Set 12 | awjilah
# Processing Record 10 of Set 12 | phan thiet
# Processing Record 11 of Set 12 | san vicente
# Processing Record 12 of Set 12 | hobyo
# Processing Record 13 of Set 12 | george
# Processing Record 14 of Set 12 | kokopo
# Processing Record 15 of Set 12 | igrim
# Processing Record 16 of Set 12 | clemson
# Processing Record 17 of Set 12 | pontes e lacerda
# Processing Record 18 of Set 12 | kurumkan
# Processing Record 19 of Set 12 | sokolo
# Processing Record 20 of Set 12 | loukhi
# Processing Record 21 of Set 12 | petrovac
# Processing Record 22 of Set 12 | calama
# Processing Record 23 of Set 12 | huarmey
# Processing Record 24 of Set 12 | dekar
# Processing Record 25 of Set 12 | klyuchevskiy
# Processing Record 26 of Set 12 | beringovskiy
# Processing Record 27 of Set 12 | ginda
# Processing Record 28 of Set 12 | tual
# Processing Record 29 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 12 | bengkulu
# Processing Record 31 of Set 12 | vichayal
# City not found. Skipping...
# Processing Record 32 of Set 12 | dauphin
# Processing Record 33 of Set 12 | jumla
# Processing Record 34 of Set 12 | husavik
# Processing Record 35 of Set 12 | atasu
# Processing Record 36 of Set 12 | abrantes
# Processing Record 37 of Set 12 | uruzgan
# Processing Record 38 of Set 12 | fort nelson
# Processing Record 39 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 40 of Set 12 | bavly
# Processing Record 41 of Set 12 | andenes
# Processing Record 42 of Set 12 | pontal do parana
# Processing Record 43 of Set 12 | hami
# Processing Record 44 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 45 of Set 12 | quatre cocos
# Processing Record 46 of Set 12 | aracati
# Processing Record 47 of Set 12 | agadez
# Processing Record 48 of Set 12 | thinadhoo
# Processing Record 49 of Set 12 | columbus
# Processing Record 50 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 2 of Set 13 | secovce
# Processing Record 3 of Set 13 | praia
# Processing Record 4 of Set 13 | garowe
# Processing Record 5 of Set 13 | khartoum
# Processing Record 6 of Set 13 | srandakan
# Processing Record 7 of Set 13 | rudbar
# Processing Record 8 of Set 13 | novouzensk
# Processing Record 9 of Set 13 | halifax
# Processing Record 10 of Set 13 | nkayi
# Processing Record 11 of Set 13 | kathmandu
# Processing Record 12 of Set 13 | atar
# Processing Record 13 of Set 13 | fairbanks
# Processing Record 14 of Set 13 | gambela
# Processing Record 15 of Set 13 | henties bay
# Processing Record 16 of Set 13 | san quintin
# Processing Record 17 of Set 13 | yuli
# Processing Record 18 of Set 13 | ruthin
# Processing Record 19 of Set 13 | cordoba
# Processing Record 20 of Set 13 | shimoda
# Processing Record 21 of Set 13 | marsh harbour
# Processing Record 22 of Set 13 | altamira
# Processing Record 23 of Set 13 | impfondo
# Processing Record 24 of Set 13 | chapais
# Processing Record 25 of Set 13 | mount pleasant
# Processing Record 26 of Set 13 | half moon bay
# Processing Record 27 of Set 13 | benjamin constant
# Processing Record 28 of Set 13 | ilulissat
# Processing Record 29 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 30 of Set 13 | taltal
# Processing Record 31 of Set 13 | lubango
# Processing Record 32 of Set 13 | price
# Processing Record 33 of Set 13 | hofn
# Processing Record 34 of Set 13 | santiago del estero
# Processing Record 35 of Set 13 | sept-iles
# Processing Record 36 of Set 13 | launceston
# Processing Record 37 of Set 13 | pemberton
# Processing Record 38 of Set 13 | kirovsk
# Processing Record 39 of Set 13 | san ramon
# Processing Record 40 of Set 13 | pisco
# Processing Record 41 of Set 13 | sao gabriel da cachoeira
# Processing Record 42 of Set 13 | denton
# Processing Record 43 of Set 13 | ziniare
# Processing Record 44 of Set 13 | atyrau
# Processing Record 45 of Set 13 | panjab
# Processing Record 46 of Set 13 | arman
# Processing Record 47 of Set 13 | torrelavega
# Processing Record 48 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 13 | oneonta
# Processing Record 50 of Set 13 | cacu
# Processing Record 1 of Set 14 | pafos
# Processing Record 2 of Set 14 | svendborg
# Processing Record 3 of Set 14 | mareeba
# Processing Record 4 of Set 14 | kuusamo
# Processing Record 5 of Set 14 | bethel
# Processing Record 6 of Set 14 | san francisco
# Processing Record 7 of Set 14 | goderich
# Processing Record 8 of Set 14 | ahuimanu
# Processing Record 9 of Set 14 | beloha
# Processing Record 10 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 11 of Set 14 | maine-soroa
# Processing Record 12 of Set 14 | tessalit
# Processing Record 13 of Set 14 | barahona
# Processing Record 14 of Set 14 | portlethen
# Processing Record 15 of Set 14 | ewa beach
# Processing Record 16 of Set 14 | longyearbyen
# Processing Record 17 of Set 14 | bhachau
# Processing Record 18 of Set 14 | lakes entrance
# Processing Record 19 of Set 14 | neuquen
# Processing Record 20 of Set 14 | kirksville
# Processing Record 21 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 22 of Set 14 | cocobeach
# Processing Record 23 of Set 14 | porto novo
# Processing Record 24 of Set 14 | ternate
# Processing Record 25 of Set 14 | camana
# Processing Record 26 of Set 14 | vostok
# Processing Record 27 of Set 14 | igarka
# Processing Record 28 of Set 14 | mtsensk
# Processing Record 29 of Set 14 | the valley
# Processing Record 30 of Set 14 | eregli
# Processing Record 31 of Set 14 | mutoko
# Processing Record 32 of Set 14 | haines junction
# Processing Record 33 of Set 14 | montmagny
# Processing Record 34 of Set 14 | stokmarknes
# Processing Record 35 of Set 14 | banda aceh
# Processing Record 36 of Set 14 | laguna
# Processing Record 37 of Set 14 | horni plana
# Processing Record 38 of Set 14 | paragould
# Processing Record 39 of Set 14 | san luis
# Processing Record 40 of Set 14 | menongue
# Processing Record 41 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 42 of Set 14 | belaya gora
# Processing Record 43 of Set 14 | benghazi
# Processing Record 44 of Set 14 | swan river
# Processing Record 45 of Set 14 | saint-pierre
# Processing Record 46 of Set 14 | shetpe
# Processing Record 47 of Set 14 | yerofey pavlovich
# Processing Record 48 of Set 14 | umm ruwabah
# City not found. Skipping...
# Processing Record 49 of Set 14 | tofte
# Processing Record 50 of Set 14 | cordele
# Processing Record 1 of Set 15 | loviisa
# Processing Record 2 of Set 15 | reviga
# Processing Record 3 of Set 15 | ampanihy
# Processing Record 4 of Set 15 | quang ngai
# Processing Record 5 of Set 15 | athabasca
# Processing Record 6 of Set 15 | dunedin
# Processing Record 7 of Set 15 | misratah
# Processing Record 8 of Set 15 | qaqortoq
# Processing Record 9 of Set 15 | nedryhayliv
# Processing Record 10 of Set 15 | proletarskiy
# Processing Record 11 of Set 15 | blackwater
# Processing Record 12 of Set 15 | krasnaya polyana
# Processing Record 13 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 15 | manyana
# Processing Record 15 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 15 | kabul
# Processing Record 17 of Set 15 | agsu
# City not found. Skipping...
# Processing Record 18 of Set 15 | zhezkazgan
# Processing Record 19 of Set 15 | ratnagiri
# Processing Record 20 of Set 15 | troitskoye
# Processing Record 21 of Set 15 | gushikawa
# Processing Record 22 of Set 15 | redcar
# Processing Record 23 of Set 15 | plouzane
# Processing Record 24 of Set 15 | mocuba
# Processing Record 25 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 15 | bilma
# Processing Record 27 of Set 15 | coihaique
# Processing Record 28 of Set 15 | lemon tree passage
# Processing Record 29 of Set 15 | pochinki
# Processing Record 30 of Set 15 | mufumbwe
# Processing Record 31 of Set 15 | luzhou
# Processing Record 32 of Set 15 | kuryk
# Processing Record 33 of Set 15 | adwa
# Processing Record 34 of Set 15 | gogrial
# Processing Record 35 of Set 15 | senec
# Processing Record 36 of Set 15 | bolshoye selo
# Processing Record 37 of Set 15 | whyalla
# Processing Record 38 of Set 15 | panaba
# Processing Record 39 of Set 15 | cacador
# Processing Record 40 of Set 15 | vila
# Processing Record 41 of Set 15 | madaoua
# Processing Record 42 of Set 15 | naze
# Processing Record 43 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 15 | ambanja
# Processing Record 45 of Set 15 | cockburn town
# Processing Record 46 of Set 15 | riviere-au-renard
# Processing Record 47 of Set 15 | canavieiras
# Processing Record 48 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 15 | lima
# Processing Record 50 of Set 15 | kidal
# Processing Record 1 of Set 16 | grindavik
# Processing Record 2 of Set 16 | bolu
# Processing Record 3 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 16 | olafsvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp          Current Description  \
# 0       Upernavik  72.7868  -56.1549     27.03             scattered clouds
# 1           Vaini -21.2000 -175.2000     62.76                   few clouds
# 2  Novobirilyussy  56.9514   90.6661     33.04              overcast clouds
# 3  Port Elizabeth -33.9180   25.5701     63.10              overcast clouds
# 4        Magnolia  33.2671  -93.2393     83.46                   few clouds
# 5            Lebu -37.6167  -73.6500     55.02                    clear sky
# 6           Bluff -46.6000  168.3333     39.79                broken clouds
# 7      Port Hardy  50.6996 -127.4199     51.98  light intensity shower rain
# 8      Bredasdorp -34.5322   20.0403     60.12              overcast clouds
# 9        Victoria  22.2855  114.1577     84.22                   light rain
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        56          37        3.04      GL
# 1       100          20        0.00      TO
# 2        97          88        4.25      RU
# 3        82          90       26.46      ZA
# 4        50          21        5.64      US
# 5        51           0       17.52      CL
# 6        79          54       10.83      NZ
# 7        87          90       21.85      CA
# 8        72          97        2.30      ZA
# 9        85           0        1.99      HK

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Upernavik      GL  72.7868  -56.1549     27.03        56          37
# 1           Vaini      TO -21.2000 -175.2000     62.76       100          20
# 2  Novobirilyussy      RU  56.9514   90.6661     33.04        97          88
# 3  Port Elizabeth      ZA -33.9180   25.5701     63.10        82          90
# 4        Magnolia      US  33.2671  -93.2393     83.46        50          21
# 5            Lebu      CL -37.6167  -73.6500     55.02        51           0
# 6           Bluff      NZ -46.6000  168.3333     39.79        79          54
# 7      Port Hardy      CA  50.6996 -127.4199     51.98        87          90
# 8      Bredasdorp      ZA -34.5322   20.0403     60.12        72          97
# 9        Victoria      HK  22.2855  114.1577     84.22        85           0
#
#    Wind Speed          Current Description
# 0        3.04             scattered clouds
# 1        0.00                   few clouds
# 2        4.25              overcast clouds
# 3       26.46              overcast clouds
# 4        5.64                   few clouds
# 5       17.52                    clear sky
# 6       10.83                broken clouds
# 7       21.85  light intensity shower rain
# 8        2.30              overcast clouds
# 9        1.99                   light rain

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "C:/Users/pampe/Desktop/WeatherlyPy/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
